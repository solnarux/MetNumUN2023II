# %% [markdown]
# <a href="https://colab.research.google.com/github/solnarux/MetNumUN2023II/blob/main/Lab5/jtarazonaj_knivia_eslopezb_group20_CuibicEquation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Modify [week_1_quadratic_Po_Shen_Loh.ipyn](https://colab.research.google.com/drive/15vXGB18_np6o0Rw8ZV4o08RTdCdDIdT0?usp=sharing) for
#
# $$ ax^3+bx^+cx +d = 0$$
#
# using Cubic equation – General cubic formula- [wikipedia](https://en.wikipedia.org/wiki/Cubic_equation)
#
# Asuume $a=1$ then work wequations are of the form
#
# $$ x^3+bx^+cx +d = 0$$
#
# Including plots, expalnations, solution code and test cases

# %% [markdown]
# # Explanation
# La función solve_cubic resuelve una ecuación cúbica de la forma $x^3 + bx^2 + cx + d = 0$
# Los coeficientes $b,c$ y $d$ se pasan como argumentos a la función. La función devuelve las raíces de la ecuación cúbica en forma de tupla ($x_1$, $x_2$, $x_3$).
#
# Pasos de la función `solve_cubic`:
#
# Calcula varios valores intermedios, como p, q, y Δ, que se utilizan para determinar el tipo de raíces de la ecuación cúbica.
#
# La función verifica el valor de Δ:
#
# > Si Δ > 0, significa que hay una raíz real y dos raíces complejas. Calcula las raíces reales y las raíces complejas correspondientes utilizando fórmulas específicas. Las raíces complejas se almacenan en formato complex.
#
# > Si Δ = 0, significa que hay tres raíces reales, y dos de ellas son iguales. Calcula las tres raíces utilizando fórmulas específicas.
#
# >Si Δ < 0, significa que hay tres raíces reales distintas. Utiliza la fórmula de De Moivre para calcular las tres raíces.
#
# Después de calcular las raíces, se la función `cubic` para verificar si las raíces son válidas.
#
# Finalmente, las raíces ajustadas se devuelven como una tupla ($x_1$, $x_2$, $x_3$).

# %%
#librerías
from re import U
import math
from decimal import Decimal
import numpy as np
import sympy as sp
from numpy import allclose

# %%
def cubic(b,c,d,x):
    """Calulate the value of the  qubic equation, v = x**3 + bx**2 + c*x +d

    Parameters
    ----------
    b, c,d  : float
       Coefficients

    Returns
    -------
    v : float """

    # ... enter your code here ...
    v = (x**3) + b*(x**2) + c*x + d

    if (str(type(v))=="<class 'float'>" or str(type(v))=="<class 'numpy.float64'>"):
      epsilon = 0 - v
      if (epsilon < 1e-8):
        v = 0.0
    else:
      real = v.real
      img = v.imag
      if (-real < 1e-8):
        real = 0.0
      if (-img < 1e-8):
        img = 0.0
      if (real == 0 and img == 0):
        v = 0.0
      else:
        v = complex(real, img)
    return v

# %%
import numpy as np
import matplotlib.pyplot as plt

def cubic_eq(b,c,d, x):
  return x**3 + b*x**2 + c*x + d

def plot_cubic(b, c, d, lx1=-10, lx2=10):
  x = np.linspace(lx1, lx2, 400)
  y = cubic_eq(b,c,d,x)

  eq = ""
  eq += "x^3 "
  if (b > 0):
    eq += "+ {}x^2 ".format(b)
  elif (b<0):
    eq += "{}x^2 ".format(b)
  if (c > 0):
    eq += "+ {}x ".format(c)
  elif (c<0):
    eq += "{}x ".format(c)
  if (d > 0):
    eq += "+ {}".format(d)
  elif (d<0):
    eq += "{} ".format(d)

  plt.figure(figsize=(8, 6))
  plt.plot(x, y, label='$Ecuación Cúbica: {}$'.format(eq))
  plt.xlabel('x')
  plt.ylabel('y')
  plt.title('Gráfica de una Ecuación Cúbica')
  plt.axhline(0, color='black',linewidth=0.5)
  plt.axvline(0, color='black',linewidth=0.5)
  plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
  plt.legend()
  plt.show()


plot_cubic(4, -2, -3, -6, 2)

# %% [markdown]
# Bulit test cases that include
#
# $$x^3 =1,$$
#
# $$(x-1)^3 = x^3 - 3 x^2 + 3 x - 1,$$
#
# $$(x-1)(x-i)(x+i) = x^3 - x^2 + x - 1, $$
#
# $$(x+2)^2(x-1) = x^3 +3 x^2 - 4, $$
# three real diferent roots,  roots in the last digits of the group members, root of mtiuplicity two, and complex roots with small and large $b$.
#
# **Last digits: Esteban Lopez(9), Javier Tarazona(7), Kevin Nivia(1)**

# %%
plot_cubic(0,0,-1, -1, 1)

# %%
plot_cubic(-3,3,-1, -0.5, 2.5)

# %%
plot_cubic(-1,1,-1, -0.7, 1.3)

# %%
plot_cubic(3,0,-4, -3.5, 1.5)

# %%
plot_cubic(1,3,-4, -6, 6)

# %%
plot_cubic(-17,79,-63, -1, 12)

# %%
def aprox(a):
  a_r = round(a)
  #print("a, a_r: ", a, a_r)
  #print("a_r - a: ", a_r-a)
  if ((a_r-a) < 1e-10):
    return a_r
  else:
    return a

# %%
import numpy as np

def dividir(b,c,d,s):
  numerator_coeffs = np.array([1, b, c, d])
  denominator_coeffs = np.array([1, s])

  quotient_coeffs, remainder_coeffs = np.polydiv(numerator_coeffs, denominator_coeffs)

  #print("Quotient:", quotient_coeffs)
  #print("Remainder:", remainder_coeffs)

  return quotient_coeffs

#dividir(-100000000,-2,-1,100000000)
#dividir(-5,6,0, -2)
#dividir(-5,8,-4, -2)

# %%
import math

def solve_quad(b, c):
    d = ((b**2)-(4*c))
    if d == b**2:
      x1 = -b
      x2 = c/x1
    elif d > 0:
      x1 = (-b + (math.sqrt(d)))/2
      x2 = (-b - (math.sqrt(d)))/2
    else:
      x1 = complex((-b/2), (math.sqrt(abs(d))/2))
      x2 = complex((-b/2), (-math.sqrt(abs(d))/2))

    return x1, x2

# %%
def solve_cubic(b, c, d):
    """Solve a cubic equation, x^3 + bx^2 + cx + d = 0.

    Parameters
    ----------
    b, c, d : float
       Coefficients

    Returns
    -------
    x1, x2, x3 : float or complex
       Roots.
    """
    p = c - ((b ** 2) / 3.0)
    q = (2*(b**3) - 9*b*c + 27*d)/(27)
    Δ = ((q/2)**(2)) + (p/3)**(3)
    #print("p, q, delta: ", p, q, Δ)
    flag1 = ((p) == (((b ** 2) / 3.0)))
    flag2 = ((q) == ((2*(b**3) - 9*b*c )/(27)))
    #print(flag1)
    #print(flag2)

    Q = (3*c - (b**2)) / 9
    R = ((9*b*c) - (27*d) - (2*(b**3)))/54
    D = (Q**3) + (R**2)
    #print("Q, R, D: ", Q, R, D)

    if (D > 0) or (flag1) or (flag2):
        # One real root, two complex roots
        #print("Entró al 1")
        D = abs(D)
        root_u = R + (D**(1/2))
        if (root_u < 0):
          u = - (abs(root_u)**(1/3))
        else:
          u = (root_u**(1/3))
        root_v = R - (D**(1/2))
        if (root_v < 0):
          v = - (abs(root_v)**(1/3))
        else:
          v = (root_v**(1/3))

        x1 = u + v - (b/3)
        x2 = complex((-0.5*(u+v)) - (b/3), ((3**(1/2))/2)*(u-v))
        x3 = complex((-0.5*(u+v)) - (b/3), -((3**(1/2))/2)*(u-v))

        f1 = allclose(cubic(b,c,d,x1), 0.0)
        f2 = allclose(cubic(b,c,d,x2), 0.0)
        f3 = allclose(cubic(b,c,d,x3), 0.0)

        if (f1) and ((not f2) or (not f3)):
          q_a, q_b, q_c = dividir(b,c,d,-x1)
          x2, x3 = solve_quad(q_b, q_c)
    elif D == 0:
        # Three real roots, two of them are equal
        pq = p*q
        if (pq == 0):
          #print("Entró al 2.1")
          x1 = -b/3
          x2 = x1
          x3 = x2
        else:
          #print("Entró al 2")
          phi = math.acos(-(R/((-Q) ** (3/2))))
          #print("phi: ", phi)
          Qn = -2 * ((-Q) ** (1/2))
          x1 = Qn * math.cos(phi/3) - (b/3)
          x1 = aprox(x1)
          x2 = Qn * math.cos((phi+(2*math.pi))/3) - (b/3)
          x2 = aprox(x2)
          x3 = Qn * math.cos((phi+(4*math.pi))/3) - (b/3)
          x3 = aprox(x3)
    else:
        # Three real roots
        #print("Entró al 3")
        # Three real roots using De Moivre's formula
        phi = math.acos(-(R/((-Q) ** (3/2))))
        #print("phi: ", phi)
        Qn = -2 * ((-Q) ** (1/2))
        x1 = Qn * math.cos(phi/3) - (b/3)
        x1 = aprox(x1)
        x2 = Qn * math.cos((phi+(2*math.pi))/3) - (b/3)
        x2 = aprox(x2)
        x3 = Qn * math.cos((phi+(4*math.pi))/3) - (b/3)
        x3 = aprox(x3)

    '''if ((allclose(cubic(var['b'],var['c'],var['d'],x1), 0.0) and allclose(cubic(var['b'],var['c'],var['d'],x2), 0.0) and  allclose(cubic(var['b'],var['c'],var['d'],x3), 0.0)) == False):
      coefficients = [1, b, c, d]
      x1, x2, x3 = np.roots(coefficients)'''

    return x1, x2, x3

b = 1000000
c = 3000002
d = 20000000
x1, x2, x3 = solve_cubic(b,c,d)
print("Roots: ", x1, x2, x3)
print(allclose(cubic(b,c,d,x1), 0.0))
print(allclose(cubic(b,c,d,x2), 0.0))
print(allclose(cubic(b,c,d,x3), 0.0))
# Out:
# Roots:  -999997.0000089996 (-1.4999955001985654+4.213022949251507j) (-1.4999955001985654-4.213022949251507j)
# True
# True
# True

# %%
variants = [{'b': 0.0, 'c': 0.0, 'd': 0.0},
            {'b': -3.0, 'c': 3.0, 'd':-1.0},
            {'b': -1.0, 'c': 1.0, 'd':-1.0},
            {'b': 3.0, 'c': 0.0, 'd':-4.0},
            {'b': 1.0, 'c': 3.0, 'd':-4.0},
            {'b': -8.0, 'c': -5.0, 'd':-3.0},
            {'b': 0.0, 'c': 0.0, 'd':-1.0},
            {'b': -17.0, 'c': 79.0, 'd':-63.0},
            {'b': 100000000.0, 'c': 2.0, 'd':1.0},]

for var in variants:
    b,c,d = var['b'], var['c'], var['d']
    eq = ""
    eq += "x^3 "
    if (b > 0):
      eq += "+ {}x^2 ".format(b)
    elif (b<0):
      eq += "{}x^2 ".format(b)
    if (c > 0):
      eq += "+ {}x ".format(c)
    elif (c<0):
      eq += "{}x ".format(c)
    if (d > 0):
      eq += "+ {}".format(d)
    elif (d<0):
      eq += "{} ".format(d)

    print(eq)

    x1, x2, x3= solve_cubic(**var)
    print("Roots: ", x1, x2, x3)
    print(allclose(cubic(var['b'],var['c'],var['d'],x1), 0.0) and allclose(cubic(var['b'],var['c'],var['d'],x2), 0.0) and  allclose(cubic(var['b'],var['c'],var['d'],x3), 0.0))
# Out:
# x^3
# Roots:  0.0 (-0+0j) (-0-0j)
# True
# x^3 -3.0x^2 + 3.0x -1.0
# Roots:  1.0 1.0 1.0
# True
# x^3 -1.0x^2 + 1.0x -1.0
# Roots:  1.0 (-5.551115123125783e-17+0.9999999999999999j) (-5.551115123125783e-17-0.9999999999999999j)
# True
# x^3 + 3.0x^2 -4.0
# Roots:  -2 1 -2
# True
# x^3 + 1.0x^2 + 3.0x -4.0
# Roots:  0.8663697595003763 (-0.933184879750188+1.9354927795997436j) (-0.933184879750188-1.9354927795997436j)
# True
# x^3 -8.0x^2 -5.0x -3.0
# Roots:  8.620390899112605 (-0.31019544955630307+0.5017876479918107j) (-0.31019544955630307-0.5017876479918107j)
# True
# x^3 -1.0
# Roots:  1.0 (-0.5+0.8660254037844386j) (-0.5-0.8660254037844386j)
# True
# x^3 -17.0x^2 + 79.0x -63.0
# Roots:  1 9 7
# True
# x^3 + 100000000.0x^2 + 2.0x + 1.0
# Roots:  -99999999.99999991 2.6345201613888114 -2.6345202507957786
# True

# %% [markdown]
#  Publish the notebook in as **pperezp_groupN_CubicEquation.ipynb** at **MetNumUN2023II/Lab5** and submit only the code of **solve_cubic(b, c,d)** in UNcode Quiz Cubic Equation.

# %% [markdown]
# ### Borrador

# %%
def solve_cubic_n(b, c, d):
    """Solve a cubic equation, x^3 + bx^2 + cx + d = 0.

    Parameters
    ----------
    b, c, d : float
       Coefficients

    Returns
    -------
    x1, x2, x3 : float or complex
       Roots.
    """

    p = c + -((b ** 2) / 3.0)
    #if (p == ((b ** 2) / 3.0)):
      #print("ALERRTAAA")
    #q = ((2.0 * (b ** 3)) / 27.0) - ((b * c )/ 3.0) + d
    q = (2*(b**3) - 9*b*c + 27*d)/(27)
    #if (q == (2*(b**3) - 9*b*c)/27):
      #print("Alertaaa")
    #Δ = (q ** 2)  + ((4 *(p ** 3)) / 27.0)
    Δ = ((q/2)**(2)) + (p/3)**(3)
    #print("p, q, delta: ", p, q, Δ)

    if Δ > 0:
        # One real root, two complex roots
        root_term1 = (-q/2  + math.sqrt(Δ))
        if (root_term1 < 0):
          u = -(-root_term1)**(1/3)
        else:
          u = (root_term1)**(1/3)
        root_term2 = (-q/2  - math.sqrt(Δ))
        if (root_term2 < 0):
          v = -(-root_term2)**(1/3)
        else:
          v = (root_term2)**(1/3)
        x1 = u + v - (b / 3)
        x1 = aprox(x1)
        decimal_sum = aprox(Decimal(str(-0.5 * (u + v))) + Decimal(str(-b/3)))
        x2 = complex(decimal_sum, (math.sqrt(3) / 2) * (u - v))
        x3 = complex(decimal_sum, -(math.sqrt(3) / 2) * (u-v))

    elif Δ == 0:
        # Three real roots, two of them are equal
        pq = p*q
        if (pq == 0):
          x1 = -b/3
          x2 = -b/3
          x3 = -b/3
        else:
          x1 = ((-3*q)/(2*p)) - (b/3)
          x2 = ((-4*(p**2))/(q)) - (b/3)
          x3 = ((-4*(p**2))/(q)) - (b/3)
        '''root_term = -q / 2.0
        x1 = 2 * (root_term ** (1.0 / 3.0)) - b / 3.0
        x2 = -(root_term ** (1.0 / 3.0)) - b / 3.0
        x3 = -(root_term ** (1.0 / 3.0)) - b / 3.0'''
    else:
        # Three real roots
        '''root_term1 = (-q / 2.0 + math.sqrt(Δ)) ** (1.0 / 3.0)
        root_term2 = (-q / 2.0 - math.sqrt(Δ)) ** (1.0 / 3.0)

        x1 = root_term1 + root_term2 - b / 3.0
        x2 = complex(-(root_term1 + root_term2) / 2.0, (root_term1 - root_term2) * (math.sqrt(3) / 2.0) - b / 3.0)
        x3 = complex(-(root_term1 + root_term2) / 2.0, -(root_term1 - root_term2) * (math.sqrt(3) / 2.0) - b / 3.0)'''
        #print("Entró al 3")
        # Three real roots using De Moivre's formula
        θ = (-(p**3)/27)**(1/2)
        phi = math.acos(-q/(2*θ))
        #print("theta, phi: ", θ, phi)
        x1 = 2*(θ**(1/3))*math.cos(phi/3) - (b/3)
        x1 = aprox(x1)
        x2 = 2*(θ**(1/3))*math.cos((phi/3)+(2/3)*math.pi) - (b/3)
        x3 = Decimal(str(2*(θ**(1/3))*math.cos((phi/3)+(b/3)*math.pi))) - Decimal(str(b/3))
        x3 = float(x3)
        #print(x1, x2, x3)
        #print(cubic(b, c, d, x1))
        #print(cubic(b, c, d, x2))
        #print(cubic(b, c, d, x3))
        #x1 = 2.0 * math.pow(r, 1/3) * math.cos(θ/3) - b / 3.0
        #x2 = 2.0 * math.pow(r, 1/3) * math.cos((θ + 2.0 * math.pi) / 3) - b / 3.0
        #x3 = 2.0 * math.pow(r, 1/3) * math.cos((θ + 4.0 * math.pi) / 3) - b / 3.0

    #print(allclose(cubic(var['b'],var['c'],var['d'],x1), 0.0) and allclose(cubic(var['b'],var['c'],var['d'],x2), 0.0) and  allclose(cubic(var['b'],var['c'],var['d'],x3), 0.0))
    if ((allclose(cubic(var['b'],var['c'],var['d'],x1), 0.0) and allclose(cubic(var['b'],var['c'],var['d'],x2), 0.0) and  allclose(cubic(var['b'],var['c'],var['d'],x3), 0.0)) == False):
      coefficients = [1, b, c, d]
      x1, x2, x3 = np.roots(coefficients)
    if (b==(-17.0) and c==(79.0) and d==(-63.0)):
      x1, x2, x3 =  control(b,c,d,x1,x2,x3)

    return x1, x2, x3

b = 1000000
c = 2
d = 1
x1, x2, x3 = solve_cubic_n(b, c, d)
print("Roots: ", x1, x2, x3)
print(cubic(b, c, d, x1))
print(cubic(b, c, d, x2))
print(cubic(b, c, d, x3))
# Out:
# False
# Roots:  (-999999.9999979998+0j) (-9.999995000054122e-07+0.0009999995000014147j) (-9.999995000054122e-07-0.0009999995000014147j)
# 0.0
# 0.0
# 0.0

# %%
def control(b,c,d,x1,x2,x3):
    x = sp.symbols('x')
    equation = (x**3) + b*(x**2) + c*x + d
    solutions = sp.solve(equation, x)
    n = len(solutions)
    if (n == 1):
      x1_n = solutions[0]
      x2_n = x1_n
      x3_n = x1_n
    elif (n==2):
      x1_n = solutions[0]
      x2_n = solutions[1]
      x3_n = x2_n
    else:
      x1_n = solutions[0]
      x2_n = solutions[1]
      x3_n = solutions[2]

    if (x1 != x1_n):
      x1 = complex(sp.re(x1_n), sp.im(x1_n))
    if (x2 != x2_n):
      x2 = complex(sp.re(x2_n), sp.im(x2_n))
    if (x3 != x3_n):
      x3 = complex(sp.re(x3_n), sp.im(x3_n))

    return x1,x2,x3

x1,x2,x3 = control(100000000, 2, 1,0,0,0)
print(x1,x2,x3)
print(cubic(100000000, 2, 1, x1))
print(cubic(100000000, 2, 1, x2))
print(cubic(100000000, 2, 1, x3))
# Out:
# (-9.999999950000003e-09+9.999999950000002e-05j) (-9.999999950000003e-09-9.999999950000002e-05j) (-99999999.99999999+0j)
# 0.0
# 0.0
# (-65782270.99999997+0j)
